# %% [markdown]
# # Predicting housing prices
# ## Goal & Approach
# The goal of our project is to **predict the final price of each home**.
# We use a dataset which includes **79 explanatory variables** describing (almost) every aspect of residential homes in Ames, Iowa.

# %%
# importing libraries that we will need:
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# %%
# reading the data from file into a pandas dataframe:
INPUT_PATH = Path.cwd() / "data"
raw_df = pd.read_csv(INPUT_PATH / "train.csv")

# %%
# selecting a subset of variables:
df = raw_df.loc[:, ["Id", "SalePrice", "YearBuilt", "GrLivArea", "TotalBsmtSF", "PoolArea", "TotRmsAbvGrd",
                    "LandSlope", "CentralAir"]]

# %% [markdown]
# ## Data Visualization

# %%
y = df.loc[:, ["SalePrice"]]
plt.plot(y)
plt.show()

# %%
# color / style

# %%
# title

# %%
# labels

# %%
# scatter

# %%
# barchart

# %%
# piechart

# %%
# histogram

# %%
# boxplot ?

# %%
# axis
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')
#plt.axis([0, 6, 0, 20])
plt.show()

# %%
# 2 plots in one graph

# %%
# legend

# %%
# 2 plots next to eachother (subplots)

# %% [markdown]
# Stuff below is from Simon

# %%
df.loc[:, ["SalePrice"]].plot.hist(bins=50)
# Out:
# <img src="data:image/png;base64,..." width="639.9333333333333">

# %%
import numpy as np
df["ln_SalePrice"] = np.log(df["SalePrice"])
df.loc[:, ["ln_SalePrice"]].plot.hist(bins=50)
# Out:
# <img src="data:image/png;base64,..." width="639.9333333333333">

# %%
df.loc[:, ["SalePrice", "CentralAir"]].boxplot(column="SalePrice", by="CentralAir")
# Out:
# <img src="data:image/png;base64,..." width="639.9333333333333">

# %%
df.loc[:, ["ln_SalePrice", "GrLivArea"]].plot.scatter(x="GrLivArea", y="ln_SalePrice")
# Out:
# <img src="data:image/png;base64,..." width="639.9333333333333">
